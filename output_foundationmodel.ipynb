# %%
from transformers import pipeline
from transformers.pipelines.pt_utils import KeyDataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
from datasets import load_dataset
import pandas as pd
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# model_path = "./pretrained_llms/Llama-3.3-70B-Instruct"
# model_path = "./pretrained_llms/Llama-3.1-8B"
model_name = "Llama-3.1-8B-Instruct"
model_path = os.path.join("./pretrained_llms", model_name)
data_path = "./data"
data_name = "mteb/tweet_sentiment_extraction"
cache_dir = "./cache"

dataset = load_dataset(data_name, cache_dir=data_path, split='train')
# dataset = load_dataset(data_name, cache_dir=data_path, split='train')
# dataset = load_dataset(data_name, cache_dir=data_path, split='train', remove_columns=["id"])
# Out:
# ./pretrained_llms/Llama-3.1-8B-Instruct

# %%
def analyze_sentiment_zero_shot(dataset, model, tokenizer, device, verbose=False, num_samples=None):
    """
    Analyze sentiment using zero-shot learning approach.
    
    Args:
        dataset: Dataset containing texts to analyze
        model: The language model
        tokenizer: The tokenizer
        device: Device to run the model on
        verbose: If True, prints each text and its prediction
        num_samples: Optional number of samples to process (None for all)
    
    Returns:
        list: List of dictionaries containing text and predictions
    """
    model.eval()
    model = model.to(device)  
    
    prompt_template = """[INST] Analyze the sentiment of the following text. Respond with exactly one word: either 'positive', 'negative', or 'neutral'.

Text: "{}"

Sentiment: [/INST]"""

    # Handle num_samples
    texts = dataset['text']
    if num_samples is not None:
        texts = texts[:num_samples]
    
    results = []
    total = len(texts)
    
    for i, text in enumerate(texts):
        prompt = prompt_template.format(text)
        inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to(device)
        
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=20,
                num_return_sequences=1,
                temperature=0.1,  # Lower temperature for more focused responses
                pad_token_id=tokenizer.pad_token_id,
                eos_token_id=tokenizer.eos_token_id
            )
            
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        # print("-"*20)
        # print(response)
        # print("-"*20)
       
        sentiment = response[len(prompt):].strip().split()[0].lower()
        
        # Store result
        results.append({
            'text': text,
            'predicted_sentiment': sentiment
        })
        
        # Verbose output
        if verbose:
            print(f"\nText [{i+1}/{total}]: {text}")
            print(f"Predicted sentiment: {sentiment}")
            
        # Print progress every 10% if not verbose
        elif (i + 1) % max(1, total // 10) == 0:
            print(f"Progress: {(i + 1) / total:.1%}")
    
    # Final progress
    if not verbose:
        print("Analysis complete!")
    
    return results

# %%
def compare_with_baseline(dataset):
    # Load a pre-trained sentiment model
    baseline_classifier = pipeline(
        "sentiment-analysis",
        model="distilbert-base-uncased-finetuned-sst-2-english",
        device=device
    )
    
    texts = dataset['text']
    
    for text in texts:
        result = baseline_classifier(text)[0]
        print(f"\nText: {text}")
        print(f"Baseline model prediction: {result}")

# %%
def evaluate_predictions(dataset, results):
    id2label = {0: "negative", 1: "neutral", 2: "positive"}
    label2id = {"negative": 0, "neutral": 1, "positive": 2}
    
    correct = 0
    total = len(results)
    confusion_matrix = {
        'negative': {'negative': 0, 'neutral': 0, 'positive': 0},
        'neutral': {'negative': 0, 'neutral': 0, 'positive': 0},
        'positive': {'negative': 0, 'neutral': 0, 'positive': 0}
    }
    
    for i, result in enumerate(results):
        true_label = id2label[dataset[i]['label']]
        # predicted = result['predicted_sentiment'].lower().strip()
        predicted = result['predicted_sentiment']        
        
        # Handle variations in predictions
        if 'positive' in predicted:
            predicted = 'positive'
        elif 'negative' in predicted:
            predicted = 'negative'
        elif 'neutral' in predicted:
            predicted = 'neutral'
        else:
            print(f"Warning: Unexpected prediction format: {predicted}")
            continue
            
        is_correct = true_label == predicted
        if is_correct:
            correct += 1
            
        # Update confusion matrix
        confusion_matrix[true_label][predicted] += 1
        
        print(f"\nText: {result['text']}")
        print(f"True label: {true_label}")
        print(f"Predicted: {predicted}")
        print(f"Correct: {is_correct}")
    
    # Calculate metrics
    accuracy = correct / total if total > 0 else 0
    
    # Print detailed results
    print("\n=== Evaluation Results ===")
    print(f"Total samples: {total}")
    print(f"Correct predictions: {correct}")
    print(f"Accuracy: {accuracy:.2%}")
    
    # Print confusion matrix
    print("\n=== Confusion Matrix ===")
    print("True\Pred\t\tNegative\tNeutral\t\tPositive")
    for true_label in ['negative', 'neutral', 'positive']:
        row = confusion_matrix[true_label]
        print(f"{true_label.title()}\t\t{row['negative']}\t\t{row['neutral']}\t\t{row['positive']}")
        
    # Calculate per-class metrics
    print("\n=== Per-Class Metrics ===")
    for label in ['negative', 'neutral', 'positive']:
        true_pos = confusion_matrix[label][label]
        false_pos = sum(conf[label] for l, conf in confusion_matrix.items() if l != label)
        false_neg = sum(confusion_matrix[label].values()) - true_pos
        
        precision = true_pos / (true_pos + false_pos) if (true_pos + false_pos) > 0 else 0
        recall = true_pos / (true_pos + false_neg) if (true_pos + false_neg) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        
        print(f"\n{label.title()} class:")
        print(f"Precision: {precision:.2%}")
        print(f"Recall: {recall:.2%}")
        print(f"F1-score: {f1:.2%}")
    
    return {
        'accuracy': accuracy,
        'confusion_matrix': confusion_matrix,
        'total_samples': total,
        'correct_predictions': correct
    }

# %%
def find_inconsistencies(dataset, results, id2label):
    inconsistent_data = []
    
    for i, result in enumerate(results):
        true_label = id2label[dataset[i]['label']]
        predicted = result['predicted_sentiment'].lower().strip()
        
        # Handle variations in predictions
        if 'positive' in predicted:
            predicted = 'positive'
        elif 'negative' in predicted:
            predicted = 'negative'
        elif 'neutral' in predicted:
            predicted = 'neutral'
        else:
            print(f"Warning: Unexpected prediction format: {predicted}")
            continue
            
        # If prediction doesn't match ground truth, add to list
        if true_label != predicted:
            inconsistent_data.append({
                'Ground Truth': true_label,
                'Predicted': predicted,
                'Text': dataset[i]['text']
            })
    
    # Create DataFrame
    df_inconsistencies = pd.DataFrame(inconsistent_data)
    
    # If there are inconsistencies, display summary
    if len(df_inconsistencies) > 0:
        print(f"\nFound {len(df_inconsistencies)} inconsistencies out of {len(dataset)} samples")
        print(f"Inconsistency rate: {(len(df_inconsistencies)/len(dataset)):.2%}")
    else:
        print("\nNo inconsistencies found!")
    
    return df_inconsistencies

id2label = {0: "negative", 1: "neutral", 2: "positive"}

df = find_inconsistencies(dataset, results, id2label)
# Display full DataFrame (not truncated)
pd.set_option('display.max_colwidth', None)
print("\nInconsistent predictions:")
print(df)
# Out:
# Warning: Unexpected prediction format: ositive
# Warning: Unexpected prediction format: ositive
#
# Found 38 inconsistencies out of 27481 samples
# Inconsistency rate: 0.14%
#
# Inconsistent predictions:
#    Ground Truth Predicted  \
# 0       neutral  positive
# 1       neutral  positive
# 2       neutral  negative
# 3      negative   neutral
# 4      negative   neutral
# 5       neutral  negative
# 6       neutral  positive
# 7       neutral  negative
# 8      negative   neutral
# 9      negative   neutral
# 10     negative  positive
# 11      neutral  negative
# 12     negative   neutral
# 13      neutral  positive
# 14     negative   neutral
# 15      neutral  negative
# 16      neutral  negative
# 17      neutral  positive
# 18      neutral  negative
# 19      neutral  negative
# 20     negative   neutral
# 21      neutral  positive
# 22     negative   neutral
# 23      neutral  negative
# 24     positive   neutral
# 25      neutral  negative
# 26      neutral  positive
# 27      neutral  positive
# 28      neutral  positive
# 29      neutral  negative
# 30      neutral  negative
# 31     positive  negative
# 32      neutral  negative
# 33      neutral  positive
# 34      neutral  positive
# 35      neutral  positive
# 36     negative  positive
# 37     positive   neutral
#
#                                                                                                                                           Text
# 0                                                 http://www.dothebouncy.com/smf - some shameless plugging for the best Rangers forum on earth
# 1                                                                                                                                   Soooo high
# 2                                   as much as i love to be hopeful, i reckon the chances are minimal =P i`m never gonna get my cake and stuff
# 3    i`ve been sick for the past few days  and thus, my hair looks wierd.  if i didnt have a hat on it would look... http://tinyurl.com/mnf4kw
# 4                                                                                                   is back home now      gonna miss every one
# 5                                                                                                                   Hes just not that into you
# 6                                                                                   oh Marly, I`m so sorry!!  I hope you find her soon!! <3 <3
# 7                                           gotta restart my computer .. I thought Win7 was supposed to put an end to the constant rebootiness
# 8                                                                                                                                   I`m sorry.
# 9                                                                                          On the way to Malaysia...no internet access to Twit
# 10               If it is any consolation I got my BMI tested hahaha it says I am obesed  well so much for being unhappy for about 10 minutes.
# 11                                                        Thats it, its the end. Tears for Fears vs Eric Prydz, DJ Hero   http://bit.ly/2Hpbg4
# 12                                                          Born and raised in NYC and living in Texas for the past 10 years!  I still miss NY
# 13                 just in case you wonder, we are really busy today and this coming with with adding tons of new blogs and updates stay tuned
# 14                                                                    i`m soooooo sleeeeepy!!! the last day o` school was today....sniffle....
# 15                                  Car not happy, big big dent in boot! Hoping theyre not going to write it off, crossing fingers and waiting
# 16                                                                                                                                    MAYDAY?!
# 17  RATT ROCKED NASHVILLE TONITE..ONE THING SUCKED, NO ENCORE!  LIKE IN THE 80`S THEY STILL HAVE A FUN SHOW. PEARCY HAS THAT HOTT BAD BOY LOOK
# 18                                                        The girl in the hair salon asked me 'Shall I trim your eyebrows!' How old do I feel?
# 19                                           Then you should check out http://twittersucks.com and connect with other tweeple who hate twitter
# 20                                                                                                          Aw. Torn ace of hearts  #Hunchback
# 21                                                                                                                                    haha yes
# 22                                                                          mannnn..... _ got an iphone!!! im jealous....  http://bit.ly/NgnaR
# 23                                                       Yay playing a show tonight! Boo it`s gonna soggy and I`m at work right before playing
# 24                                                                                                                                    Chilliin
# 25                                                                                                        I still smell of smoke  #kitchenfire
# 26                         Anyone have an extra Keane ticket? I promise to buy you a drink and take rad pics for your FB / Blog / Flickr., etc
# 27                                                           'you can ride one, you can catch one, but its not summer til you pop open one'  ?
# 28                     she is good! so gor-juz yea i kno i asked her yesterday when we were at tha hospital if she talked to u and she said no
# 29                                                                                                                           My sources say no
# 30                                                                        Hey, you change your twitter account, and you didn`t even tell me...
# 31                                                                                    lucky kid...i so wanna see loserville  pity im in oz....
# 32                                                                                                            fell asleep waiting for my ride!
# 33                 Miles from you   I`m in Essex so give me plenty of warning so I can arrive in time to get at least one of those free beers.
# 34         His snoring is so annoying n it keeps me from sleeping (like right now, lol) but I honestly wud miss it if it eva left  I love him.
# 35                                                                                               _Mounce yes and it lasts way past my bedtime!
# 36                CASEY`S GONE?!?! BUT WHY?! So, she piddled a little on the carpet. She`s prolly freaked cause it`s new. Can we get her back?
# 37                                                                                              We saw that in none 3D - the baddie`s the best

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_path, 
    torch_dtype="auto",
    cache_dir=cache_dir
)
tokenizer = AutoTokenizer.from_pretrained(
    model_path,
    add_eos_token=True,
    cache_dir=cache_dir
)

if tokenizer.pad_token_id is None:
    print("No pad token found, setting pad token to eos token")
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id
    tokenizer.padding_side = "right"
    model.resize_token_embeddings(len(tokenizer))
    model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# No pad token found, setting pad token to eos token

# %%
# print("=== Testing Raw Outputs ===")
# test_raw_outputs(dataset, model, tokenizer, device)

print("\n=== Testing with Instruction Prompts ===")
# results = analyze_sentiment_zero_shot(dataset, model, tokenizer, device)
results = analyze_sentiment_zero_shot(dataset, model, tokenizer, device, verbose=False, num_samples=100)

# print("\n=== Comparing with Baseline Model ===")
# compare_with_baseline(dataset)
# Out:
# === Testing with Instruction Prompts ===
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 60.0%
# Progress: 70.0%
# Progress: 80.0%
# Progress: 90.0%
# Progress: 100.0%
# Analysis complete!

# %%
metrics = evaluate_predictions(dataset, results)
# Out:
# Text:  I`d have responded, if I were going
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text:  Sooo SAD I will miss you here in San Diego!!!
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: my boss is bullying me...
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  what interview! leave me alone
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  Sons of ****, why couldn`t they put them on the releases we already bought
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: http://www.dothebouncy.com/smf - some shameless plugging for the best Rangers forum on earth
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: 2am feedings for the baby are fun when he is all smiles and coos
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: Soooo high
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text:  Both of you
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text:  Journey!? Wow... u just became cooler.  hehe... (is that possible!?)
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  as much as i love to be hopeful, i reckon the chances are minimal =P i`m never gonna get my cake and stuff
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: I really really like the song Love Story by Taylor Swift
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: My Sharpie is running DANGERously low on ink
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: i want to go to music tonight but i lost my voice.
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: test test from the LG enV2
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: Uh oh, I am sunburned
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  S`ok, trying to plot alternatives as we speak *sigh*
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: i`ve been sick for the past few days  and thus, my hair looks wierd.  if i didnt have a hat on it would look... http://tinyurl.com/mnf4kw
# True label: negative
# Predicted: neutral
# Correct: False
#
# Text: is back home now      gonna miss every one
# True label: negative
# Predicted: neutral
# Correct: False
#
# Text: Hes just not that into you
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text:  oh Marly, I`m so sorry!!  I hope you find her soon!! <3 <3
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: Playing Ghost Online is really interesting. The new updates are Kirin pet and Metamorph for third job.  Can`t wait to have a dragon pet
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: is cleaning the house for her family who is comming later today..
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: gotta restart my computer .. I thought Win7 was supposed to put an end to the constant rebootiness
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: SEe waT I Mean bOuT FoLL0w fRiiDaYs... It`S cALLed LoSe f0LloWeRs FridAy... smH
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: the free fillin` app on my ipod is fun, im addicted
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:   I`m sorry.
# True label: negative
# Predicted: neutral
# Correct: False
#
# Text: On the way to Malaysia...no internet access to Twit
# True label: negative
# Predicted: neutral
# Correct: False
# Warning: Unexpected prediction format: ositive
#
# Text: Went to sleep and there is a power cut in Noida  Power back up not working too
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: I`m going home now. Have you seen my new twitter design? Quite....heavenly isn`****?
# True label: positive
# Predicted: positive
# Correct: True
# Warning: Unexpected prediction format: ositive
#
# Text:  If it is any consolation I got my BMI tested hahaha it says I am obesed  well so much for being unhappy for about 10 minutes.
# True label: negative
# Predicted: positive
# Correct: False
#
# Text:  That`s very funny.  Cute kids.
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  Ahhh, I slept through the game.  I`m gonna try my best to watch tomorrow though. I hope we play Army.
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: Thats it, its the end. Tears for Fears vs Eric Prydz, DJ Hero   http://bit.ly/2Hpbg4
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: Born and raised in NYC and living in Texas for the past 10 years!  I still miss NY
# True label: negative
# Predicted: neutral
# Correct: False
#
# Text: just in case you wonder, we are really busy today and this coming with with adding tons of new blogs and updates stay tuned
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: i`m soooooo sleeeeepy!!! the last day o` school was today....sniffle....
# True label: negative
# Predicted: neutral
# Correct: False
#
# Text: A little happy for the wine jeje ok it`sm my free time so who cares, jaja i love this day
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  Car not happy, big big dent in boot! Hoping theyre not going to write it off, crossing fingers and waiting
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: im an avid fan of **** magazine and i love your magazines
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: MAYDAY?!
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: RATT ROCKED NASHVILLE TONITE..ONE THING SUCKED, NO ENCORE!  LIKE IN THE 80`S THEY STILL HAVE A FUN SHOW. PEARCY HAS THAT HOTT BAD BOY LOOK
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text:  I love to! But I`m only available from 5pm.  and where dear? Would love to help  convert her vids.ï¿½
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: The girl in the hair salon asked me 'Shall I trim your eyebrows!' How old do I feel?
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: egh blah and boooooooooooo i dunno wanna go to work  HANGOVERS SUCKKKKKK Im a drunk mess!
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: :visiting my friendster and facebook
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: i donbt like to peel prawns, i also dont like going shopping, running out of money and crawling round the car looking for more
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  which case? I got a new one last week and I`m not thrilled at all with mine.
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  Then you should check out http://twittersucks.com and connect with other tweeple who hate twitter
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text:  also bored at school, its my third freelesson( freistunde )
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text:  hm... Both of us I guess...
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text:  it is ****...u have dissappointed me that past few days
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  romance zero is funny
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  I`d rather do the early run..but I am a morning runner
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: Bah a coworker ran into work late and her bag smacked into my knee  it really hurts now
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: will be back later.  http://plurk.com/p/rp3k7
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: Aw. Torn ace of hearts  #Hunchback
# True label: negative
# Predicted: neutral
# Correct: False
#
# Text:  what fun are you speaking of?
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: i lost all my friends, i`m alone and sleepy..i wanna go home
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  haha yes
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: I give in to easily
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: What better way to spoil mum than to let her kick back and relax over a nice meal and a bottle of her favorite wine? Our wine was a red
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: mannnn..... _ got an iphone!!! im jealous....  http://bit.ly/NgnaR
# True label: negative
# Predicted: neutral
# Correct: False
#
# Text: Is at a photoshoot.
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text:   He`s awesome... Have you worked with him before? He`s a good friend.
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: Yay playing a show tonight! Boo it`s gonna soggy and I`m at work right before playing
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: Chilliin
# True label: positive
# Predicted: neutral
# Correct: False
#
# Text:  If you know such agent, do let me know
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: I still smell of smoke  #kitchenfire
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text:  a celtics-lakers rematch sounds better don`t you think? lol
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: Anyone have an extra Keane ticket? I promise to buy you a drink and take rad pics for your FB / Blog / Flickr., etc
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: 'you can ride one, you can catch one, but its not summer til you pop open one'  ?
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text:  she is good! so gor-juz yea i kno i asked her yesterday when we were at tha hospital if she talked to u and she said no
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: OK - I`m out of here for now. Just popped in to say Hi and check on things. I`ll probably head to the guttah later on tonight
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: WOW, i AM REALLY MiSSiN THE FAM(iLY) TODAY. BADDD.
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  My sources say no
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: I am sooo tired
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  Hey, you change your twitter account, and you didn`t even tell me...
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text:  THANK YYYYYYYYYOOOOOOOOOOUUUUU!
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  lucky kid...i so wanna see loserville  pity im in oz....
# True label: positive
# Predicted: negative
# Correct: False
#
# Text: fell asleep waiting for my ride!
# True label: neutral
# Predicted: negative
# Correct: False
#
# Text: Sick. With a flu like thing.
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: Still no reply from  about my SimFinger problem  So no iRape parody video until I get a response, sorry guys
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: Happy Star Wars day everyone! and Enjoy the holiday (UK)
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  Miles from you   I`m in Essex so give me plenty of warning so I can arrive in time to get at least one of those free beers.
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: His snoring is so annoying n it keeps me from sleeping (like right now, lol) but I honestly wud miss it if it eva left  I love him.
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text: i miss you bby      wish you were going tomorrow to make me do good.
# True label: negative
# Predicted: negative
# Correct: True
#
# Text:  Well what im working on isn`t QUITE ready to post about publicly (still beta testing) but its a cool new script I coded
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  SWEEEEET - San Fran is awesome!!!!  Love it there
# True label: positive
# Predicted: positive
# Correct: True
#
# Text: _Mounce yes and it lasts way past my bedtime!
# True label: neutral
# Predicted: positive
# Correct: False
#
# Text:  Hi  how are you doing ???  *just joined twitter...*
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: waiting for sleeping pills to kick in... gonna be so tired at work tomorrow
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: eating ice cream and then getting ready for graduation.
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text: Happy Mothers day to all you Mums out there
# True label: positive
# Predicted: positive
# Correct: True
#
# Text:  CASEY`S GONE?!?! BUT WHY?! So, she piddled a little on the carpet. She`s prolly freaked cause it`s new. Can we get her back?
# True label: negative
# Predicted: positive
# Correct: False
#
# Text:  hemp cloth is marvelous but unfortunately no
# True label: negative
# Predicted: negative
# Correct: True
#
# Text: Gonna read a story bout adam lambert online then bed. Nighty night
# True label: neutral
# Predicted: neutral
# Correct: True
#
# Text:  We saw that in none 3D - the baddie`s the best
# True label: positive
# Predicted: neutral
# Correct: False
#
# === Evaluation Results ===
# Total samples: 100
# Correct predictions: 60
# Accuracy: 60.00%
#
# === Confusion Matrix ===
# True\Pred		Negative	Neutral		Positive
# Negative		23		8		2
# Neutral		13		18		12
# Positive		1		2		19
#
# === Per-Class Metrics ===
#
# Negative class:
# Precision: 62.16%
# Recall: 69.70%
# F1-score: 65.71%
#
# Neutral class:
# Precision: 64.29%
# Recall: 41.86%
# F1-score: 50.70%
#
# Positive class:
# Precision: 57.58%
# Recall: 86.36%
# F1-score: 69.09%

# %%
print(model.config.eos_token_id)
# Out:
# 128001

# %%
dataset[0]

# %%
model = AutoModelForSequenceClassification.from_pretrained(model_path, num_labels=3, torch_dtype="auto")
tokenizer = AutoTokenizer.from_pretrained(model_path,
                                          add_eos_token=True,
                                          cache_dir=cache_dir)
if tokenizer.pad_token_id is None:
    print("No pad token found, setting pad token to eos token")
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id
    tokenizer.padding_side = "right"
    model.resize_token_embeddings(len(tokenizer))
    model.config.pad_token_id = tokenizer.pad_token_id
    
classifier = pipeline(task="sentiment-analysis", model=model, tokenizer=tokenizer, device=device, padding=True, truncation=True, max_length=512)

# %%
for out in classifier(KeyDataset(dataset, "text"), batch_size=8):
    print(out)

# %%
tokens = classifier.tokenizer(["Example text", "I am a boy"], padding=True, truncation=True)
print(tokens)
print(classifier.tokenizer.pad_token)
